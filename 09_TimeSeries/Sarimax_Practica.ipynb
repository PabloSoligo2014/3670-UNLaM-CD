# %% [markdown]
# # Series de tiempo - Sarimax

# %% [markdown]
# Se tiene una serie de tiempo con las temperaturas de una turbina puesta en funcionamiento continuo. El objetivo es hacer un pronóstico de la evolución de la temperatura a una ventana de n puntos a futuro (los timestamp no son reales).
# ¿Puede SARIMAX mejorar un pronostico ingenuo?

# %%
#!pip install statsmodels
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller
from itertools import product
from statsmodels.tsa.statespace.sarimax import SARIMAX
import seaborn as sns
import scipy.stats as stats
#Test estadistico sobre la normalidad de los residuos
from scipy.stats import shapiro
from statsmodels.graphics.gofplots import qqplot

# %% [markdown]
# Carga de datos

# %%
channel_name = 'sensor_temp'
df_cmapss = pd.read_csv('../datasets/train_FD001.txt', sep=r"\s+", header=None)
df = df_cmapss[df_cmapss[0] == 1].copy()
df.set_index(1, inplace=True)
df = df[[6]].rename(columns={6: 'sensor_temp'})
df.shape
# Out:
# (192, 1)

# %% [markdown]
# Sarimax necesita fechas, las agregamos. Usamos un periodo de "dia", no es importante, podria ser minutos o segundos, para nosotros es lo mismo

# %%
fdates = pd.date_range(start='2026-01-01', periods=len(df), freq='D')
df.index = fdates

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.index, df[channel_name], label='Sensor Temp (Unit 1)')
plt.title('Serie Temporal del Sensor de Temperatura (Unit 1)')
plt.xlabel('Ciclo')
plt.ylabel('Temperatura')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ¿Hay nulos?

# %%
#Si, columnas hay una sola, pero lo dejamos genérico para otros casos
for c in df.columns:
    print(f"{c}: {df[c].isnull().sum()} nulos")
# Out:
# sensor_temp: 0 nulos

# %% [markdown]
# ¿Hay duplicados?

# %%
df.index.duplicated().any()
# Out:
# False

# %% [markdown]
# ---------------------

# %% [markdown]
# La periodicidad es estable, un problema resuelto.

# %% [markdown]
# -------

# %% [markdown]
# ### 1. ¿Tiene la serie propiedades para poder aplicar un modelo estadístico? Verificar y actuar en consecuencia.

# %% [markdown]
# ### 2. ¿Puede encontrar un modelo que supere el pronóstico ingenuo que agregamos al pie?

# %% [markdown]
# ### 3. Si intenta una búsqueda de órden p y q ¿Puede restringir al menos un poco las opciones de búsqueda?

# %% [markdown]
# ![alt text](image.png)

# %% [markdown]
# ### 4.¿Los residuos del pronóstico son aproximadamente normales?

# %% [markdown]
# ### 5.¿Puede hacer una mejor predicción?

# %% [markdown]
# ![image.png](attachment:image.png)
