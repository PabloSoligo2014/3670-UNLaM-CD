# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier # vecinos más cercanos para clasificación
from sklearn.metrics import accuracy_score # métrica de evaluación
from sklearn.metrics import classification_report

# %% [markdown]
# # Análisis Exploratorio

# %%
df_smokers = pd.read_csv('https://raw.githubusercontent.com/pokengineer/DataScience/main/datasets/smokers.csv')
df_smokers.head(5)
# Out:
#    age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  eyesight(right)  \
# 0   35         170          85       97.0             0.9              0.9
# 1   20         175         110      110.0             0.7              0.9
# 2   45         155          65       86.0             0.9              0.9
# 3   45         165          80       94.0             0.8              0.7
# 4   20         165          60       81.0             1.5              0.1
#
#    hearing(left)  hearing(right)  systolic  relaxation  ...  HDL  LDL  \
# 0              1               1       118          78  ...   70  142
# 1              1               1       119          79  ...   71  114
# 2              1               1       110          80  ...   57  112
# 3              1               1       158          88  ...   46   91
# 4              1               1       109          64  ...   47   92
#
#    hemoglobin  Urine protein  serum creatinine   AST   ALT  Gtp  \
# 0        19.8              1               1.0    61   115  125
# 1        15.9              1               1.1    19    25   30
# 2        13.7              3               0.6  1090  1400  276
# 3        16.9              1               0.9    32    36   36
# 4        14.9              1               1.2    26    28   15
#
#    dental caries  smoking
# 0              1        1
# 1              1        0
# 2              0        0
# 3              0        0
# 4              0        0
#
# [5 rows x 23 columns]

# %%
# verificamos los tipos de datos
df_smokers.dtypes
# Out:
# age                      int64
# height(cm)               int64
# weight(kg)               int64
# waist(cm)              float64
# eyesight(left)         float64
# eyesight(right)        float64
# hearing(left)            int64
# hearing(right)           int64
# systolic                 int64
# relaxation               int64
# fasting blood sugar      int64
# Cholesterol              int64
# triglyceride             int64
# HDL                      int64
# LDL                      int64
# hemoglobin             float64
# Urine protein            int64
# serum creatinine       float64
# AST                      int64
# ALT                      int64
# Gtp                      int64
# dental caries            int64
# smoking                  int64
# dtype: object

# %%
print("Tamaño del dataframe : {}".format(df_smokers.shape))
# Out:
# Tamaño del dataframe : (38984, 23)

# %%
# Verificamos si hay valores nulos para imputar
df_smokers.isnull().sum()
# Out:
# age                    0
# height(cm)             0
# weight(kg)             0
# waist(cm)              0
# eyesight(left)         0
# eyesight(right)        0
# hearing(left)          0
# hearing(right)         0
# systolic               0
# relaxation             0
# fasting blood sugar    0
# Cholesterol            0
# triglyceride           0
# HDL                    0
# LDL                    0
# hemoglobin             0
# Urine protein          0
# serum creatinine       0
# AST                    0
# ALT                    0
# Gtp                    0
# dental caries          0
# smoking                0
# dtype: int64

# %%
# Analisis de la distribución de la variable target "smoking"
print( df_smokers.smoking.value_counts() )
sns.countplot(x='smoking', data=df_smokers, hue='smoking', legend=False)
# Out:
# smoking
# 0    24666
# 1    14318
# Name: count, dtype: int64
# <Axes: xlabel='smoking', ylabel='count'>

# %%
plt.figure(figsize=(4, 8))
s=sns.boxplot(x="smoking", y="weight(kg)", data=df_smokers, hue="smoking", legend=False)
s.plot()
# Out:
# []

# %% [markdown]
# # Correlación de Variables

# %%
plt.figure(figsize=(14,7))
sns.heatmap(df_smokers.corr(), annot=True, vmax=.7, cmap ='Blues', fmt=".2f")
# Out:
# <Axes: >

# %%
df_smokers_corr = df_smokers.corr()[["smoking"]]*100 # lo pasamos a porcentajes
df_smokers_corr = df_smokers_corr.drop("smoking", axis=0) # eliminamos la variable target
df_smokers_corr = df_smokers_corr.sort_values(["smoking"], ascending=False) # ordenamos en forma descendente
df_smokers_corr = abs(df_smokers_corr) # nos interesa el valor absouluto
df_smokers_corr
# Out:
#                        smoking
# hemoglobin           40.120561
# height(cm)           39.431445
# weight(kg)           29.934668
# triglyceride         25.105661
# Gtp                  24.027443
# waist(cm)            22.335903
# serum creatinine     21.247301
# dental caries        10.760060
# relaxation           10.366297
# fasting blood sugar   9.990846
# ALT                   9.861475
# systolic              7.017624
# eyesight(right)       6.458676
# AST                   6.283387
# eyesight(left)        5.940882
# Urine protein         1.365274
# hearing(right)        1.898955
# hearing(left)         2.207703
# Cholesterol           2.749314
# LDL                   4.162746
# age                  16.626845
# HDL                  17.950944

# %% [markdown]
# # Seleccionamos y Escalamos las variables que vamos a utilizar

# %%
# definimos df con las 10 columnas que elegimos para el modelo
# sería lo mismo que hacer un drop de las que no queremos
df = df_smokers[['hemoglobin', 'height(cm)', 'weight(kg)', 'triglyceride', 'Gtp',
       'waist(cm)', 'serum creatinine', 'dental caries', 'relaxation',
       'fasting blood sugar','smoking']]

# %%
# Hacemos el Split 70-30 para train-test
y_smokers = df["smoking"]
X_train, X_test, y_train, y_test = train_test_split(df.drop(["smoking"],axis = 1), y_smokers, test_size=0.3, stratify = y_smokers, random_state=42)

# %%
# usamos StandardScaler para escalar las variables
scaler_X = StandardScaler(with_mean=True, with_std=True)
scaler_X.fit(X_train) # entrenamos los valores quitandole la variable clase
# Out:
# StandardScaler()

# %%
X_train = scaler_X.transform(X_train)
X_test = scaler_X.transform(X_test)

# %%
test_scores = []

# Creamos y entrenamos el algoritmo con 20 valores de K
for k in range(3,40,2):
  knn = KNeighborsClassifier(k)
  knn.fit(X_train,y_train) # Creamos y entrenamos el clasificador knn

  # Para cada valor de K, evaluamos la capacidad de clasificación con datos de prueba
  y_pred = knn.predict(X_test)
  test_scores.append(accuracy_score(y_test, y_pred)) # Agregamos los K resultados de evaluación

# %%
df_scores = pd.DataFrame([{"k":valor_k, "score":test_scores_k} for valor_k, test_scores_k in zip(range(3,40,2),test_scores)])
plt.plot(df_scores["k"], df_scores["score"])

# %%
df_scores
# Out:
#      k     score
# 0    3  0.710157
# 1    5  0.710072
# 2    7  0.712209
# 3    9  0.714432
# 4   11  0.716228
# 5   13  0.716057
# 6   15  0.715373
# 7   17  0.715800
# 8   19  0.716741
# 9   21  0.719220
# 10  23  0.717938
# 11  25  0.719562
# 12  27  0.719135
# 13  29  0.721101
# 14  31  0.719904
# 15  33  0.720075
# 16  35  0.719306
# 17  37  0.721272
# 18  39  0.722640

# %%
# Entrenamos el algoritmo con el mejor K
knn = KNeighborsClassifier( 11 )
knn.fit(X_train,y_train) # Entrenamos el clasificador
# Out:
# KNeighborsClassifier(n_neighbors=11)

# %%
y_pred_knn = knn.predict(X_test)

#Exactitud del modelo
print('Exactitud (accuracy) del modelo: {:.2f} %'.format(accuracy_score(y_test, y_pred_knn)*100))
print("-"*100)

# Reporte del clasificador
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_knn))
# Out:
# Exactitud (accuracy) del modelo: 71.62 %
# ----------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.77      0.78      0.78      7400
#            1       0.62      0.61      0.61      4296
#
#     accuracy                           0.72     11696
#    macro avg       0.69      0.69      0.69     11696
# weighted avg       0.72      0.72      0.72     11696

# %% [markdown]
# # Ejercicio
# Dado el análisis exploratorio concluimos que no hace falta imputar variables y que la variable target esta balanceada.
# - Usando el mapa de calor de correlaciones, ¿que pares de columnas comparten más de un 0.7 de correlación?
# - Entrenar un modelo con K menor a 11, comparar los resultados
# - Entrenar un modelo con K mayor a 11, comparar los resultados
# - Entrenar un modelo con 3 variables, seleccionar un K apropiado y comparar los resultados
# - Entrenar un modelo con todas las variables, seleccionar un K apropiado y comparar los resultados
# - "Feature Engineering", Crear una columna nueva no redundante, entrenar un modelo y comparar los resultados

# %% [markdown]
# Uso de MLExtend en remplazo de SelectFromModel/SequentialFeatureSelector o metodos de filtados (univariables) como SelectKBest.

# %% [markdown]
# Me puedo dar este lujo porque el dataset es pequeño. Aprovecho tambien la oportunidad para aplicar maxmin en lugar de StandardScaler

# %%
from sklearn.preprocessing import MinMaxScaler
X_train, X_test, y_train, y_test = train_test_split(df.drop(["smoking"],axis = 1), df["smoking"], test_size=0.3, stratify = y_smokers, random_state=42)
scaler_X = MinMaxScaler(feature_range=(0, 1)) # escalamos los valores entre 0 y 1
scaler_X.fit(X_train) # entrenamos los valores quitandole la variable clase

X_train = scaler_X.transform(X_train)
X_test = scaler_X.transform(X_test)

# %%
from mlxtend.feature_selection import ExhaustiveFeatureSelector as EFS
from sklearn.neighbors import KNeighborsClassifier
import time
min_features = 3
max_features = 5

# %%
knn = KNeighborsClassifier(n_neighbors=11)

efs = EFS(
    knn, 
    min_features=min_features, 
    max_features=max_features, # Evalúa hasta el total de columnas
    scoring='accuracy',
    cv=5,
    print_progress=True
)

efs = efs.fit(X_train, y_train)

print('Mejor combinación de índices:', efs.best_idx_)
print('Mejor puntaje:', efs.best_score_)

X_train_efs = efs.transform(X_train)
X_test_efs = efs.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 12
#       8     cv=5,
#       9     print_progress=True
#      10 )
#      11
# ---> 12 efs = efs.fit(X_train, y_train)
#      13
#      14 print('Mejor combinación de índices:', efs.best_idx_)
#      15 print('Mejor puntaje:', efs.best_score_)
#
# File ~/git/3670-UNLaM-CD/.venv/lib/python3.12/site-packages/mlxtend/feature_selection/exhaustive_feature_selector.py:452, in ExhaustiveFeatureSelector.fit(self, X, y, groups, **fit_params)
#     449 n_jobs = min(self.n_jobs, all_comb)
#     450 parallel = Parallel(n_jobs=n_jobs, pre_dispatch=self.pre_dispatch)
#     451 work = enumerate(
# --> 452     parallel(
#     453         delayed(_calc_score)(
#     454             self,
#     455             X_,
#     456             y,
#     457             list(set(c).union(self.fixed_features_group_set)),
#     458             groups=groups,
#     459             feature_groups=self.feature_groups,
#     460             **fit_params,
#     461         )
#     462         for c in candidates
#     463     )
#     464 )
#     466 try:
#     467     for iteration, (indices, cv_scores) in work:
#
# File ~/git/3670-UNLaM-CD/.venv/lib/python3.12/site-packages/joblib/parallel.py:2012, in Parallel.__call__(self, iterable)
#    2010     output = self._get_sequential_output(iterable)
#    2011     next(output)
# -> 2012     return output if self.return_generator else list(output)
#    2014 # Let's create an ID that uniquely identifies the current call. If the
#    2015 # call is interrupted early and that the same instance is immediately
#    2016 # reused, this id will be used to prevent workers that were
#    2017 # concurrently finalizing a task from the previous call to run the
#    2018 # callback.
#    2019 with self._lock:
#
# File ~/git/3670-UNLaM-CD/.venv/lib/python3.12/site-packages/joblib/parallel.py:1940, in Parallel._get_sequential_output(self, iterable)
#    1938 self.n_dispatched_batches += 1
#    1939 self.n_dispatched_tasks += 1
# -> 1940 res = func(*args, **kwargs)
#    1941 self.n_completed_tasks += 1
#    1942 self.print_progress()
#
# File ~/git/3670-UNLaM-CD/.venv/lib/python3.12/site-packages/mlxtend/feature_selection/utilities.py:100, in _calc_score(selector, X, y, indices, groups, feature_groups, **fit_params)
#      97 param_name = "fit_params" if sklearn_version < "1.4" else "params"
#      99 if selector.cv:
# --> 100     scores = cross_val_score(
#     101         selector.est_,
#     102         X[:, IDX],
#     103         y,
#     104         groups=groups,
#     105         cv=selector.cv,
#     106         scoring=selector.scorer,
#     107         n_jobs=1,
#     108         pre_dispatch=selector.pre_dispatch,
#     109         **{param_name: fit_params},
#     110     )
#     111 else:
#     112     selector.est_.fit(X[:, IDX], y, **fit_params)
#
# File ~/git/3670-UNLaM-CD/.venv/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/git/3670-UNLaM-CD/.venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:650, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, error_score)
#     647 # To ensure multimetric format is not supported
#     648 scorer = check_scoring(estimator, scoring=scoring)
# --> 650 cv_results = cross_validate(
#     651     estimator=estimator,
#     652     X=X,
#     653     y=y,
#     654     groups=groups,
#     655     scoring={"score": scorer},
#     656     cv=cv,
#     657     n_jobs=n_jobs,
#     658     verbose=verbose,
#     659     params=params,
#     660     pre_dispatch=pre_dispatch,
#     661     error_score=error_score,
#     662 )
#     663 return cv_results["test_score"]
#
# File ~/git/3670-UNLaM-CD/.venv/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/git/3670-UNLaM-CD/.venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:372, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     369 # We clone the estimator to make sure that all the folds are
#     370 # independent, and that it is pickle-able.
#     371 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 372 results = parallel(
#     373     delayed(_fit_and_score)(
#     374         clone(estimator),
#     375         X,
#     376         y,
#     377         scorer=scorers,
#     378         train=train,
#     379         test=test,
#     380         verbose=verbose,
#     381         parameters=None,
#     382         fit_params=routed_params.estimator.fit,
#     383         score_params=routed_params.scorer.score,
#     384         return_train_score=return_train_score,
#     385         return_times=True,
#     386         return_estimator=return_estimator,
#     387         error_score=error_score,
#     388     )
#     389     for train, test in indices
#     390 )
#     392 _warn_or_raise_about_fit_failures(results, error_score)
#     394 # For callable scoring, the return type is only know after calling. If the
#     395 # return type is a dictionary, the error scores can now be inserted with
#     396 # the correct key.
#
# File ~/git/3670-UNLaM-CD/.venv/lib/python3.12/site-packages/sklearn/utils/parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~/git/3670-UNLaM-CD/.venv/lib/python3.12/site-packages/joblib/parallel.py:2012, in Parallel.__call__(self, iterable)
#    2010     output = self._get_sequential_output(iterable)
#    2011     next(output)
# -> 2012     return output if self.return_generator else list(output)
#    2014 # Let's create an ID that uniquely identifies the current call. If the
#    2015 # call is interrupted early and that the same instance is immediately
#    2016 # reused, this id will be used to prevent workers that were
#    2017 # concurrently finalizing a task from the previous call to run the
#    2018 # callback.
#    2019 with self._lock:
#
# File ~/git/3670-UNLaM-CD/.venv/lib/python3.12/site-packages/joblib/parallel.py:1940, in Parallel._get_sequential_output(self, iterable)
#    1938 self.n_dispatched_batches += 1
#    1939 self.n_dispatched_tasks += 1
# -> 1940 res = func(*args, **kwargs)
#    1941 self.n_completed_tasks += 1
#    1942 self.print_progress()
#
# File ~/git/3670-UNLaM-CD/.venv/lib/python3.12/site-packages/sklearn/utils/parallel.py:184, in _FuncWrapper.__call__(self, *args, **kwargs)
#     180                 this_warning_filter_dict[special_key] = this_value.pattern
#     182         warnings.filterwarnings(**this_warning_filter_dict, append=True)
# --> 184 return self.function(*args, **kwargs)
#
# File ~/git/3670-UNLaM-CD/.venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:878, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score, caller, callback_ctx)
#     875 result["fit_error"] = None
#     877 fit_time = time.time() - start_time
# --> 878 test_scores = _score(
#     879     estimator, X_test, y_test, scorer, score_params_test, error_score
#     880 )
#     881 score_time = time.time() - start_time - fit_time
#     882 if return_train_score:
#
# File ~/git/3670-UNLaM-CD/.venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:945, in _score(estimator, X_test, y_test, scorer, score_params, error_score)
#     943         scores = scorer(estimator, X_test, **score_params)
#     944     else:
# --> 945         scores = scorer(estimator, X_test, y_test, **score_params)
#     946 except Exception:
#     947     if isinstance(scorer, _MultimetricScorer):
#     948         # If `_MultimetricScorer` raises exception, the `error_score`
#     949         # parameter is equal to "raise".
#
# File ~/git/3670-UNLaM-CD/.venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py:167, in _MultimetricScorer.__call__(self, estimator, *args, **kwargs)
#     165 try:
#     166     if isinstance(scorer, _BaseScorer):
# --> 167         score = scorer._score(
#     168             cached_call, estimator, *args, **routed_params.get(name).score
#     169         )
#     170     else:
#     171         score = scorer(estimator, *args, **routed_params.get(name).score)
#
# File ~/git/3670-UNLaM-CD/.venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py:455, in _Scorer._score(self, method_caller, estimator, X, y_true, **kwargs)
#     453 pos_label = None if is_regressor(estimator) else self._get_pos_label()
#     454 response_method = _check_response_method(estimator, self._response_method)
# --> 455 y_pred = method_caller(
#     456     estimator,
#     457     _get_response_method_name(response_method),
#     458     X,
#     459     pos_label=pos_label,
#     460 )
#     462 scoring_kwargs = {**self._kwargs, **kwargs}
#     463 return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#
# File ~/git/3670-UNLaM-CD/.venv/lib/python3.12/site-packages/sklearn/metrics/_scorer.py:97, in _cached_call(cache, estimator, response_method, *args, **kwargs)
#      94 if cache is not None and response_method in cache:
#      95     return cache[response_method]
# ---> 97 result, _ = _get_response_values(
#      98     estimator, *args, response_method=response_method, **kwargs
#      99 )
#     101 if cache is not None:
#     102     cache[response_method] = result
#
# File ~/git/3670-UNLaM-CD/.venv/lib/python3.12/site-packages/sklearn/utils/_response.py:215, in _get_response_values(estimator, X, response_method, pos_label, return_response_method_used)
#     212     elif pos_label is None:
#     213         pos_label = classes[-1]
# --> 215 y_pred = prediction_method(X)
#     217 if prediction_method.__name__ in ("predict_proba", "predict_log_proba"):
#     218     y_pred = _process_predict_proba(
#     219         y_pred=y_pred,
#     220         target_type=target_type,
#     221         classes=classes,
#     222         pos_label=pos_label,
#     223     )
#
# File ~/git/3670-UNLaM-CD/.venv/lib/python3.12/site-packages/sklearn/neighbors/_classification.py:278, in KNeighborsClassifier.predict(self, X)
#     275         return self.classes_[np.argmax(probabilities, axis=1)]
#     276     # In that case, we do not need the distances to perform
#     277     # the weighting so we do not compute them.
# --> 278     neigh_ind = self.kneighbors(X, return_distance=False)
#     279     neigh_dist = None
#     280 else:
#
# File ~/git/3670-UNLaM-CD/.venv/lib/python3.12/site-packages/sklearn/neighbors/_base.py:916, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     911     if issparse(X):
#     912         raise ValueError(
#     913             "%s does not work with sparse matrices. Densify the data, "
#     914             "or set algorithm='brute'" % self._fit_method
#     915         )
# --> 916     chunked_results = Parallel(n_jobs, prefer="threads")(
#     917         delayed(self._tree.query)(X[s], n_neighbors, return_distance)
#     918         for s in gen_even_slices(X.shape[0], n_jobs)
#     919     )
#     920 else:
#     921     raise ValueError("internal: _fit_method not recognized")
#
# File ~/git/3670-UNLaM-CD/.venv/lib/python3.12/site-packages/sklearn/utils/parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~/git/3670-UNLaM-CD/.venv/lib/python3.12/site-packages/joblib/parallel.py:2012, in Parallel.__call__(self, iterable)
#    2010     output = self._get_sequential_output(iterable)
#    2011     next(output)
# -> 2012     return output if self.return_generator else list(output)
#    2014 # Let's create an ID that uniquely identifies the current call. If the
#    2015 # call is interrupted early and that the same instance is immediately
#    2016 # reused, this id will be used to prevent workers that were
#    2017 # concurrently finalizing a task from the previous call to run the
#    2018 # callback.
#    2019 with self._lock:
#
# File ~/git/3670-UNLaM-CD/.venv/lib/python3.12/site-packages/joblib/parallel.py:1940, in Parallel._get_sequential_output(self, iterable)
#    1938 self.n_dispatched_batches += 1
#    1939 self.n_dispatched_tasks += 1
# -> 1940 res = func(*args, **kwargs)
#    1941 self.n_completed_tasks += 1
#    1942 self.print_progress()
#
# File ~/git/3670-UNLaM-CD/.venv/lib/python3.12/site-packages/sklearn/utils/parallel.py:184, in _FuncWrapper.__call__(self, *args, **kwargs)
#     180                 this_warning_filter_dict[special_key] = this_value.pattern
#     182         warnings.filterwarnings(**this_warning_filter_dict, append=True)
# --> 184 return self.function(*args, **kwargs)
#
# KeyboardInterrupt:
