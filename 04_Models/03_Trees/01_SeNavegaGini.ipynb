# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.preprocessing import OrdinalEncoder
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report
# Crear el DataFrame con los datos
data = [
    ['Soleado', 'Muy Fuerte', "No"],
    ['Soleado', 'Fuerte', "Si" ],
    ['Soleado', 'Normal', "Si" ],
    ['Soleado', 'Nulo', "No" ],
    
    ['Nublado', 'Muy Fuerte', "No"],
    ['Nublado', 'Fuerte', "No" ],
    ['Nublado', 'Normal', "Si" ],
    ['Nublado', 'Nulo', "No" ],
    
    ['Lluvia', 'Muy Fuerte', "No"],
    ['Lluvia', 'Fuerte', "No" ],
    ['Lluvia', 'Normal', "Si" ],
    ['Lluvia', 'Nulo', "No" ],

]


df = pd.DataFrame(data, columns=['Cielo', 'Viento', 'Navega'])
df
# Out:
#       Cielo      Viento Navega
# 0   Soleado  Muy Fuerte     No
# 1   Soleado      Fuerte     Si
# 2   Soleado      Normal     Si
# 3   Soleado        Nulo     No
# 4   Nublado  Muy Fuerte     No
# 5   Nublado      Fuerte     No
# 6   Nublado      Normal     Si
# 7   Nublado        Nulo     No
# 8    Lluvia  Muy Fuerte     No
# 9    Lluvia      Fuerte     No
# 10   Lluvia      Normal     Si
# 11   Lluvia        Nulo     No

# %%
oe = OrdinalEncoder(categories=[['Soleado', 'Nublado', 'Lluvia'], ['Nulo', 'Normal',  'Fuerte', 'Muy Fuerte'], ['No', 'Si']], dtype=int)
df.loc[:, ["OCielo", "OViento", "ONavega"]] = oe.fit_transform(df)

# %%
# Separar las características y las etiquetas
X = df[["OCielo", "OViento"]]
y = df['ONavega']
model = DecisionTreeClassifier(max_depth=2, criterion='gini')
model.fit(X, y)
# Crear y entrenar el árbol de decisión
# Visualizar el árbol de decisión
plt.figure(figsize=(10, 10))
plot_tree(model, feature_names=X.columns, class_names=oe.inverse_transform(df[["OCielo", "OViento", "ONavega"]])[:, 2], filled=True)
plt.show()

# %%
y_pred = model.predict(X)
print(classification_report(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94         8
#            1       1.00      0.75      0.86         4
#
#     accuracy                           0.92        12
#    macro avg       0.94      0.88      0.90        12
# weighted avg       0.93      0.92      0.91        12

# %% [markdown]
# Agregemos un nivel mas al arbol...Tenemos una rama que no aporta

# %%
# Separar las características y las etiquetas
X = df[["OCielo", "OViento"]]
y = df['ONavega']
model = DecisionTreeClassifier(max_depth=3, criterion='gini')
model.fit(X, y)
# Crear y entrenar el árbol de decisión
# Visualizar el árbol de decisión
plt.figure(figsize=(10, 10))
plot_tree(model, feature_names=X.columns, class_names=oe.inverse_transform(df[["OCielo", "OViento", "ONavega"]])[:, 2], filled=True)
plt.show()
y_pred = model.predict(X)
print(classification_report(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94         8
#            1       1.00      0.75      0.86         4
#
#     accuracy                           0.92        12
#    macro avg       0.94      0.88      0.90        12
# weighted avg       0.93      0.92      0.91        12

# %%
# Separar las características y las etiquetas
X = df[["OCielo", "OViento"]]
y = df['ONavega']
model = DecisionTreeClassifier(max_depth=4, criterion='gini')
model.fit(X, y)
# Crear y entrenar el árbol de decisión
# Visualizar el árbol de decisión
plt.figure(figsize=(10, 10))
plot_tree(model, 
          feature_names=X.columns, 
          class_names=oe.inverse_transform(df[["OCielo", "OViento", "ONavega"]])[:, 2], 
          fontsize=10,
          filled=True)
plt.show()
y_pred = model.predict(X)
print(classification_report(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         8
#            1       1.00      1.00      1.00         4
#
#     accuracy                           1.00        12
#    macro avg       1.00      1.00      1.00        12
# weighted avg       1.00      1.00      1.00        12
